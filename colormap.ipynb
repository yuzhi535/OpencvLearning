# %%
import cv2 as cv
import numpy as np

# %%
img = cv.imread('./images/04176_grandtetonsunrise_2560x1600.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.show()

# %%
out_img = cv.applyColorMap()
